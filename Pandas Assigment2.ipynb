# %%
import pandas as pd

# %%
import pymysql as mysql

# %%
con=mysql.connect(host='localhost',user='root',password='root',database='test1')

# %%
df=pd.read_sql_query('select * from student',con)
df
# Out:
#    id   name
# 0   1  aaaaa
# 1   2   bbbb
# 2   3    ccc

# %%
df=pd.read_json('iris.json')
df
# Out:
#      petalLength  petalWidth  sepalLength  sepalWidth    species
# 0            1.4         0.2          5.1         3.5     setosa
# 1            1.4         0.2          4.9         3.0     setosa
# 2            1.3         0.2          4.7         3.2     setosa
# 3            1.5         0.2          4.6         3.1     setosa
# 4            1.4         0.2          5.0         3.6     setosa
# 5            1.7         0.4          5.4         3.9     setosa
# 6            1.4         0.3          4.6         3.4     setosa
# 7            1.5         0.2          5.0         3.4     setosa
# 8            1.4         0.2          4.4         2.9     setosa
# 9            1.5         0.1          4.9         3.1     setosa
# 10           1.5         0.2          5.4         3.7     setosa
# 11           1.6         0.2          4.8         3.4     setosa
# 12           1.4         0.1          4.8         3.0     setosa
# ...

# %%
# nasted json file
import json
from pandas.io.json import json_normalize

# %%
f=open('monthlySalesbyCategoryMultiple.json')
data=json.load(f)
data
# Out:
# {'contents': [{'category': 'Furniture',
#    'region': 'West',
#    'monthlySales': [{'month': 20130101, 'sales': 38},
#     {'month': 20130201, 'sales': 35},
#     {'month': 20130301, 'sales': 41},
#     {'month': 20130401, 'sales': 55},
#     {'month': 20130501, 'sales': 58},
#     {'month': 20130601, 'sales': 66},
#     {'month': 20130701, 'sales': 74},
#     {'month': 20130801, 'sales': 78},
#     {'month': 20130901, 'sales': 38},
#     {'month': 20131001, 'sales': 30},
#     {'month': 20131101, 'sales': 26},
#     {'month': 20131201, 'sales': 29}]},
#   {'category': 'Technology',
#    'region': 'West',
#    'monthlySales': [{'month': 20130101, 'sales': 54},
#     {'month': 20130201, 'sales': 66},
#     {'month': 20130301, 'sales': 77},
#     {'month': 20130401, 'sales': 70},
#     {'month': 20130501, 'sales': 60},
#     {'month': 20130601, 'sales': 63},
#     {'month': 20130701, 'sales': 55},
#     {'month': 20130801, 'sales': 47},
#     {'month': 20130901, 'sales': 55},
# ...

# %%
df=json_normalize(data['contents'])
df
# Out:
#      category                                       monthlySales region
# 0   Furniture  [{'month': 20130101, 'sales': 38}, {'month': 2...   West
# 1  Technology  [{'month': 20130101, 'sales': 54}, {'month': 2...   West

# %%
df.columns
# Out:
# Index(['category', 'monthlySales', 'region'], dtype='object')
